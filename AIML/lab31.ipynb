# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.Pclass.unique())
# Out:
# [3 1 2]

# %%
from matplotlib import pyplot as plt

# %%
# function to make bar plot of number of male, female and mean fair
values = {
    'male':df['Sex'].tolist().count('male'),
    'female':df['Sex'].tolist().count('female'),
    'mean_fair':df['Fare'].mean()
}
values
# Out:
# {'male': 577, 'female': 314, 'mean_fair': 32.204207968574636}

# %%
# bar plot
fig,ax = plt.subplots(figsize=(20,10))
plt.bar(list(values.keys()),list(values.values()),color='maroon')
plt.xlabel("Men and Women Mean fair")
plt.ylabel("Values")
datas = list(values.values())
for i,data in enumerate(datas):
    plt.text(x=i,y=data+1,s=f"{int(data)}",fontdict=dict(fontsize=10))
plt.tight_layout()
    
plt.show()

# %%
#make line chart 
plt.plot(list(df['Pclass']),list(df['Age']))

# %%
plt.plot(df['Pclass'],df['Survived'])

# %%
import seaborn as sns
sns.lineplot(x="Age",y="Fare",hue='Sex',data=df)
plt.show()

# %%
sns.histplot(df,x=df['Age'],hue=df['Sex'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
df.boxplot(by='Survived',column=['Age','Fare','Pclass'])
# Out:
# array([[<AxesSubplot:title={'center':'Age'}, xlabel='Survived'>,
#         <AxesSubplot:title={'center':'Fare'}, xlabel='Survived'>],
#        [<AxesSubplot:title={'center':'Pclass'}, xlabel='Survived'>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.boxplot(x='Survived',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(x='Survived',y='Fare',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
#Scatter plot (2D and 3D) in between age and fare and insert label
ax = sns.scatterplot(x='Age',y='Fare',data=df,hue='Sex')
ax.set(xlabel='Age',ylabel='Fare')
plt.show()

# %%
# Display each class with different colours in scatterplot using searborn
sns.pairplot(data=df,hue='Sex')

# %%
# Plot the boxplot for individual feature.

sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
#  Draw a violin plot.
sns.violinplot(data=df,y='Fare',x='Pclass')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
#  Draw a kdeplot
sns.kdeplot(data=df,x='Survived',y='Pclass',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
new_df = df.drop(['PassengerId'],axis=1)

# %%
sns.relplot(x='Age',y='Fare',col='Sex',data=new_df,hue='Survived')
