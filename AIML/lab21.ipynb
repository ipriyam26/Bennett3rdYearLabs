# %% [markdown]
# ### Lab 1 Week 2
# ## by Priyam Srivastava - E20CSE479
# ![Alt Text](https://media.giphy.com/media/scZPhLqaVOM1qG4lT9/giphy.gif)

# %%
import pandas as pd
df = pd.read_csv('unclean_data.csv')
df
# Out:
#      Time          Date  Pulse_rate  Maxpulse  Calories
# 0    60.0  '2020/12/01'       110.0     130.0     409.1
# 1    45.0  '2020/12/04'       109.0     175.0       NaN
# 2    45.0  '2020/12/05'       117.0     148.0     406.0
# 3    60.0  '2020/12/06'       102.0     127.0     300.0
# 4     NaN  '2020/12/07'       110.0     136.0     374.0
# 5   450.0  '2020/12/08'       104.0     134.0     253.3
# 6    60.0  '2020/12/12'       100.0     120.0     250.7
# 7    60.0  '2020/12/12'       100.0     120.0     250.7
# 8    60.0  '2020/12/13'       106.0     128.0     345.3
# 9    60.0  '2020/12/14'       104.0       NaN     379.3
# 10   45.0  '2020/12/18'        90.0     112.0       NaN
# 11   60.0  '2020/12/19'       103.0     123.0     323.0
# 12   45.0  '2020/12/20'        97.0     125.0     243.0
# 13   60.0  '2020/12/21'       108.0     131.0     364.2
# 14   45.0           NaN       100.0     119.0     282.0
# 15   60.0  '2020/12/23'       130.0     101.0       NaN
# ...

# %%
df[:10]
# Out:
#     Time          Date  Pulse_rate  Maxpulse  Calories
# 0   60.0  '2020/12/01'       110.0     130.0     409.1
# 1   45.0  '2020/12/04'       109.0     175.0       NaN
# 2   45.0  '2020/12/05'       117.0     148.0     406.0
# 3   60.0  '2020/12/06'       102.0     127.0     300.0
# 4    NaN  '2020/12/07'       110.0     136.0     374.0
# 5  450.0  '2020/12/08'       104.0     134.0     253.3
# 6   60.0  '2020/12/12'       100.0     120.0     250.7
# 7   60.0  '2020/12/12'       100.0     120.0     250.7
# 8   60.0  '2020/12/13'       106.0     128.0     345.3
# 9   60.0  '2020/12/14'       104.0       NaN     379.3

# %%
df.tail(10)
# Out:
#      Time       Date  Pulse_rate  Maxpulse  Calories
# 5   120.0 2020-12-19       104.0     134.0     253.3
# 6    60.0 2020-12-20       100.0     120.0     250.7
# 7    60.0 2020-12-30       100.0     120.0     250.7
# 8    60.0 2020-12-31       106.0     128.0     345.3
# 11   60.0 2020-12-30       103.0     123.0     323.0
# 12   45.0 2020-12-31        97.0     125.0     243.0
# 13   60.0 2020-12-21       108.0     131.0     364.2
# 18   60.0 2020-12-29       100.0     132.0     280.0
# 19   60.0 2020-12-30       102.0     129.0     380.3
# 20   60.0 2020-12-31        92.0     115.0     243.0

# %%
df.count()
# Out:
# Time          20
# Date          20
# Pulse_rate    20
# Maxpulse      20
# Calories      17
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'Date', 'Pulse_rate', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.dtypes
# Out:
# Time          float64
# Date           object
# Pulse_rate    float64
# Maxpulse      float64
# Calories      float64
# dtype: object

# %%
df.isna().any()
# Out:
# Time          True
# Date          True
# Pulse_rate    True
# Maxpulse      True
# Calories      True
# dtype: bool

# %%
#find number of missing values in each column
df.isna().sum()
# Out:
# Time          1
# Date          1
# Pulse_rate    1
# Maxpulse      1
# Calories      4
# dtype: int64

# %%
df.dropna()
# Out:
#      Time          Date  Pulse_rate  Maxpulse  Calories
# 0    60.0  '2020/12/01'       110.0     130.0     409.1
# 2    45.0  '2020/12/05'       117.0     148.0     406.0
# 3    60.0  '2020/12/06'       102.0     127.0     300.0
# 5   450.0  '2020/12/08'       104.0     134.0     253.3
# 6    60.0  '2020/12/12'       100.0     120.0     250.7
# 7    60.0  '2020/12/12'       100.0     120.0     250.7
# 8    60.0  '2020/12/13'       106.0     128.0     345.3
# 11   60.0  '2020/12/19'       103.0     123.0     323.0
# 12   45.0  '2020/12/20'        97.0     125.0     243.0
# 13   60.0  '2020/12/21'       108.0     131.0     364.2
# 18   60.0  '2020/12/29'       100.0     132.0     280.0
# 19   60.0  '2020/12/30'       102.0     129.0     380.3
# 20   60.0  '2020/12/31'        92.0     115.0     243.0

# %%
df.dropna(inplace=True)
df
# Out:
#      Time          Date  Pulse_rate  Maxpulse  Calories
# 0    60.0  '2020/12/01'       110.0     130.0     409.1
# 2    45.0  '2020/12/05'       117.0     148.0     406.0
# 3    60.0  '2020/12/06'       102.0     127.0     300.0
# 5   450.0  '2020/12/08'       104.0     134.0     253.3
# 6    60.0  '2020/12/12'       100.0     120.0     250.7
# 7    60.0  '2020/12/12'       100.0     120.0     250.7
# 8    60.0  '2020/12/13'       106.0     128.0     345.3
# 11   60.0  '2020/12/19'       103.0     123.0     323.0
# 12   45.0  '2020/12/20'        97.0     125.0     243.0
# 13   60.0  '2020/12/21'       108.0     131.0     364.2
# 18   60.0  '2020/12/29'       100.0     132.0     280.0
# 19   60.0  '2020/12/30'       102.0     129.0     380.3
# 20   60.0  '2020/12/31'        92.0     115.0     243.0

# %%
# check if there is there any wrong format entry of ‘date’ in the dataset. If you find any 
# wrong date format correct it in the form of YYYY-MM-DD
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#      Time       Date  Pulse_rate  Maxpulse  Calories
# 0    60.0 2020-12-01       110.0     130.0     409.1
# 2    45.0 2020-12-08       117.0     148.0     406.0
# 3    60.0 2020-12-12       102.0     127.0     300.0
# 5   450.0 2020-12-19       104.0     134.0     253.3
# 6    60.0 2020-12-20       100.0     120.0     250.7
# 7    60.0 2020-12-30       100.0     120.0     250.7
# 8    60.0 2020-12-31       106.0     128.0     345.3
# 11   60.0 2020-12-30       103.0     123.0     323.0
# 12   45.0 2020-12-31        97.0     125.0     243.0
# 13   60.0 2020-12-21       108.0     131.0     364.2
# 18   60.0 2020-12-29       100.0     132.0     280.0
# 19   60.0 2020-12-30       102.0     129.0     380.3
# 20   60.0 2020-12-31        92.0     115.0     243.0

# %%
# Set the maximum time as 120 in the ‘time’ column of the dataset
df.Time.clip(upper=120, inplace=True)
df
# Out:
#      Time       Date  Pulse_rate  Maxpulse  Calories
# 0    60.0 2020-12-01       110.0     130.0     409.1
# 2    45.0 2020-12-08       117.0     148.0     406.0
# 3    60.0 2020-12-12       102.0     127.0     300.0
# 5   120.0 2020-12-19       104.0     134.0     253.3
# 6    60.0 2020-12-20       100.0     120.0     250.7
# 7    60.0 2020-12-30       100.0     120.0     250.7
# 8    60.0 2020-12-31       106.0     128.0     345.3
# 11   60.0 2020-12-30       103.0     123.0     323.0
# 12   45.0 2020-12-31        97.0     125.0     243.0
# 13   60.0 2020-12-21       108.0     131.0     364.2
# 18   60.0 2020-12-29       100.0     132.0     280.0
# 19   60.0 2020-12-30       102.0     129.0     380.3
# 20   60.0 2020-12-31        92.0     115.0     243.0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                 Time  Pulse_rate  Maxpulse  Calories
# Time        1.000000   -0.047457  0.061513 -0.279145
# Pulse_rate -0.047457    1.000000  0.840550  0.816059
# Maxpulse    0.061513    0.840550  1.000000  0.620313
# Calories   -0.279145    0.816059  0.620313  1.000000

# %%
df.describe()
# Out:
#              Time  Pulse_rate    Maxpulse    Calories
# count   13.000000   13.000000   13.000000   13.000000
# mean    62.307692  103.153846  127.846154  311.430769
# std     18.213478    6.229582    8.153181   63.594344
# min     45.000000   92.000000  115.000000  243.000000
# 25%     60.000000  100.000000  123.000000  250.700000
# 50%     60.000000  102.000000  128.000000  300.000000
# 75%     60.000000  106.000000  131.000000  364.200000
# max    120.000000  117.000000  148.000000  409.100000

# %%
df.drop_duplicates(inplace=True)
